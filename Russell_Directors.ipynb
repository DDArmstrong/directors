# %%
import pandas as pd

# %%
# https://docs.google.com/spreadsheets/d/1P6c94fstrtpHeA3IkMyNMHpzK0p_WnJQdaXlS2g66rU/edit?usp=sharing
Directors = "https://docs.google.com/spreadsheets/d/1P6c94fstrtpHeA3IkMyNMHpzK0p_WnJQdaXlS2g66rU/edit?usp=sharing"
Directors = Directors.replace('/edit?usp=sharing', '/export?format=csv')

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1P6c94fstrtpHeA3IkMyNMHpzK0p_WnJQdaXlS2g66rU/export?format=csv')

# %% [markdown]
# ## Median ages of boards of Russell 3,000

# %%
pd.set_option('display.max_rows', 10000)
df.groupby('Company')['Age'].median().sort_values(ascending = False)
# Out:
# Company
# Investors Title Company                     78.0
# Alexander's, Inc.                           77.0
# National Beverage Corp.                     76.0
# Westamerica Bancorporation                  76.0
# Daily Journal Corporation                   75.5
# Healthcare Trust Of America Inc             75.0
# Siebert Financial Corp.                     74.0
# RPC, Inc.                                   74.0
# Marine Products Corp.                       74.0
# Marcus & Millichap Inc                      74.0
# AXT Inc                                     74.0
# Independence Holding Company                73.5
# Gladstone Commercial Corporation            73.0
# Territorial Bancorp Inc                     73.0
# Rollins, Inc.                               73.0
# Gladstone Land Corp                         73.0
# Mantech International Corp                  72.0
# MarineMax Inc                               72.0
# New York Community Bancorp, Inc.            72.0
# ...

# %% [markdown]
# ## Ages of board 45,000 or so board members

# %%
# df['Age'].describe()
# df['Name'].describe()
df.hist(column='Age',bins=25)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# ## Median ages of company boards

# %%
df_medianage = df.groupby('Company')['Age'].median()
df_medianage.hist(bins = 25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## The company with the oldest median board

# %%
df[df['Company'].str.contains('Investors Title Company')]
# Out:
#                        Company Reuters Ticker               Name   Age  \
# 21156  Investors Title Company         ITIC.O   David L. Francis  86.0
# 21157  Investors Title Company         ITIC.O        H. Joe King  86.0
# 21158  Investors Title Company         ITIC.O      J. Allen Fine  84.0
# 21159  Investors Title Company         ITIC.O   James Allen Fine  57.0
# 21160  Investors Title Company         ITIC.O     James H. Speed  62.0
# 21161  Investors Title Company         ITIC.O    James R. Morton  81.0
# 21162  Investors Title Company         ITIC.O  R. Horace Johnson  74.0
# 21163  Investors Title Company         ITIC.O  Richard M. Hutson  78.0
# 21164  Investors Title Company         ITIC.O     W. Morris Fine  52.0
#
#                                                 Position  Appointed Ticker
# 21156                               Independent Director     1982.0   ITIC
# 21157                               Independent Director     1983.0   ITIC
# ...

# %% [markdown]
# ## The company with the youngest median board

# %%
df[df['Company'].str.contains('Greenlane Holdings Inc')]
# Out:
#                       Company Reuters Ticker             Name   Age  \
# 17859  Greenlane Holdings Inc         GNLN.O   Aaron LoCascio  33.0
# 17860  Greenlane Holdings Inc         GNLN.O  Adam Schoenfeld  34.0
# 17861  Greenlane Holdings Inc         GNLN.O      Ethan Rudin  44.0
# 17862  Greenlane Holdings Inc         GNLN.O  Jay M. Scheiner  63.0
# 17863  Greenlane Holdings Inc         GNLN.O      Sasha Kadey  34.0
#
#                                              Position  Appointed Ticker
# 17859  Chairman of the Board, Chief Executive Officer     2018.0   GNLN
# 17860                Director, Chief Strategy Officer     2018.0   GNLN
# 17861                         Chief Financial Officer     2019.0   GNLN
# 17862                         Chief Operating Officer     2015.0   GNLN
# 17863                         Chief Marketing Officer     2016.0   GNLN

# %% [markdown]
# ## The oldest and youngest board members in America

# %%
(df[df.Age == df.Age.max()])
# Out:
#                            Company Reuters Ticker           Name   Age  \
# 25392  Mercury General Corporation            MCY  George Joseph  97.0
#
#                     Position  Appointed Ticker
# 25392  Chairman of the Board     2006.0    MCY

# %% [markdown]
# "Born Sept. 11, 1921, Joseph was raised during the heart of the Great Depression by parents who emigrated to the U.S. from Lebanon. His father worked as a coal miner and storekeeper in Beckley, West Virginia ("The Gateway to Southern West Virginia"), where the family raised pigs and chickens and grew vegetables." https://www.mercuryinsurance.com/about/george-joseph.html

# %%
(df[df.Age == df.Age.min()])
# Out:
#                 Company Reuters Ticker              Name   Age  Position  \
# 26465  MSG Networks Inc         MSGN.A  Quentin F. Dolan  25.0  Director
#
#        Appointed Ticker
# 26465     2015.0   MSGN

# %% [markdown]
#     ## Keep it in the family. Nepotism!

# %% [markdown]
# Board members of MSG Networks
# James L. Dolan
# Charles F. Dolan
# Charles P. Dolan
# Kristin A. Dolan
# Marianne Dolan Weber
# Paul J. Dolan
# Ryan T. Dolan
# Thomas C. Dolan
#
# Quentin F. Dolan  --->  "a graduate of NYU, intern at Grubman Shire & Meiselas, P.C. and Azoff MSG Entertainment, and has significant familiarity with the Company’s business as a member of the third generation of Cablevision Systems Corporation’s founding family.
#
# Isiah L. Thomas III

# %% [markdown]
# ## Who is on the most boards? (The Liberty Media/John Malone Mafia)

# %%
df['Name'].value_counts().head(20)
# Out:
# Gregory B. Maffei          16
# Albert E. Rosenthaler      12
# John C. Malone             12
# Brian J. Wendling          11
# Robert R. Bennett           9
# Evan Daniel Malone          8
# Larry E. Romrell            8
# Renee L. Wilm               8
# Andrea L. Wong              8
# David E. Rapley             7
# M. Ian G. Gilchrist         6
# .. ..                       6
# Brian M. Deevy              6
# J. David Wargo              6
# Elisha W. Finney            5
# John Michael Losh           5
# Kelly A. Ayotte             5
# Alan G. Spoon               5
# Jonathan N. Christodoro     5
# Nelson Peltz                5
# Name: Name, dtype: int64

# %% [markdown]
# Greg Maffei (born May 24, 1960) is an American businessman. He is the president and chief executive officer of Liberty Media and the chairman of Live Nation Entertainment, Sirius XM and TripAdvisor. He is the chairman emeritus of Starz and Expedia, as well as the former chief financial officer of Oracle and Microsoft. https://en.wikipedia.org/wiki/Greg_Maffei
#
# David E. Raply has over 30 years of experience as a founder, executive, manager and director of various engineering firms.  He founded Rapley Engineering in 1985 and, as its President and Chief Executive Officer, oversaw its development into a full service engineering firm at the time of its sale to VECO Corporation (VECO) in 1998.  Following the sale, David served as Executive Vice President, Engineering of VECO, an Alaska-based firm providing engineering, design, construction and project management services to the energy, chemical and process industries domestically and internationally, until December 2001. https://www.libertyglobal.com/leadership/david-e-rapley/
#
# Brian M. Deevy has been a director of Liberty Media Corporation since June 2015. He previously served as the head of Royal Bank of Canada (RBC) Capital Markets’ Communications, Media & Entertainment (CME) Group. Mr. Deevy was responsible for strategic development of the CME Group’s business, which included mergers & acquisitions, private equity and debt capital formation, and financial advisory engagements. https://ir.libertymedia.com/class-iii-bod/brian-deevy
#
# M. Ian G. Gilchrist has been a director since July 2009. Mr. Gilchrist was a Managing Director of Citigroup/Salomon Brothers from 1995 until his retirement in July 2008. Prior to 1995, he was a Managing Director of CS First Boston Corporation and a Managing Director of PaineWebber Incorporated. https://ir.libertymedia.com/class-iii-bod/m-ian-gilchrist
#
# J. David Wargo has over 35 years of experience in investment research, analysis and management.  He is the Founder and President of Wargo & Company, Inc., a private company specialising in investing in the communications industry since 1993.  David is a co-founding member of Peters Creek Entertainment LLC from 2010 and is a co-founding member of Asia Vision LLC since 2015.  In addition, he is a co-founder and was a member of New Mountain Capital, LLC from 2000 to 2008. https://www.libertyglobal.com/leadership/j-david-wargo/

# %%
df1 = df[(df['Name']) == 'Gregory B. Maffei']
df2 = df[(df['Name']) == 'John C. Malone']
df3 = df[(df['Name']) == 'Albert E. Rosenthaler']
df4 = df[(df['Name']) == 'Robert R. Bennett']
df5 = df[(df['Name']) == 'Renee L. Wilm']
df6 = df[(df['Name']) == 'Larry E. Romrell']
df7 = df[(df['Name']) == 'Andrea L. Wong']
df8 = df[(df['Name']) == 'Evan Daniel Malone']
df9 = df[(df['Name']) == 'David E. Rapley']
df10 = df[(df['Name']) == 'Brian M. Deevy']
df11 = df[(df['Name']) == 'M. Ian G. Gilchrist']
df12 = df[(df['Name']) == 'J. David Wargo']
df13 = df[(df['Name']) == 'David V. Singer']
df14 = df[(df['Name']) == 'Kelly A. Ayotte']
df15 = df[(df['Name']) == 'Brian J. Wendling']

df1.to_csv("Maffei")
df2.to_csv("Malone1")
df3.to_csv("Rosenthaler")
df4.to_csv("Wendling'")
df5.to_csv("Bennett")
df6.to_csv("Wilm")
df7.to_csv("Romrell")
df8.to_csv("Wong")
df9.to_csv("Malone2")
df10.to_csv("Rapley")
df11.to_csv("Deevy")
df12.to_csv("Gilchrist")
df13.to_csv("Wargo")
df14.to_csv("Singer")
df15.to_csv("Ayotte")
